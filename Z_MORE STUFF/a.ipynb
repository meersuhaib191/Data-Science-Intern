# %%
five =[1 , 4 , 6 ,8,10 , 9, 0, 6 , 7]
five[0]
five[-1]
x = len(five)//2
five[x]
# Out:
# 10

# %%
five.append(1)
five
# Out:
# [1, 4, 6, 8, 10, 9, 0, 6, 7, 1]

# %%
five[2]= 2
five
# Out:
# [1, 4, 2, 8, 10, 9, 0, 6, 7, 1]

# %%
[x for x in five if x!=10]
# Out:
# [1, 4, 2, 8, 9, 0, 6, 7, 1]

# %%
five.remove(10)

# %%
print(five)
# Out:
# [1, 4, 2, 8, 9, 0, 6, 7, 1]

# %%
for x in five :
    print(x)
# Out:
# 1
# 4
# 2
# 8
# 9
# 0
# 6
# 7
# 1

# %%
i = 0 
while i < len(five) :
    print(five[i])
    i += 1
# Out:
# 1
# 4
# 2
# 8
# 9
# 0
# 6
# 7
# 1

# %%
len(five)
# Out:
# 9

# %%
five.count(1)
# Out:
# 2

# %%
max = five[0]
for x in five :
    if five[0] < x :
        max = x
print(max)
# Out:
# 7

# %%
five.sort()
five[-1]
# Out:
# 9

# %%
rev = []
for i in range(len(five) - 1, -1, -1):
    rev.append(five[i])

print(rev)
# Out:
# [9, 8, 7, 6, 4, 2, 1, 1, 0]

# %%
seen=[]
for x in five :
    if x in seen :
        continue
    else :
        seen.append(x)

print(seen)
# Out:
# [0, 1, 2, 4, 6, 7, 8, 9]

# %%
t1 = (2,4,6,8,5,4)

# %%
t1[1]
# Out:
# 4

# %%
t1[-2]
# Out:
# 5

# %%
a = list(t1)
[a]
# Out:
# [[2, 4, 6, 8, 5, 4]]

# %%
a.append(4)

# %%
a
# Out:
# [2, 4, 6, 8, 5, 4, 4]

# %%
t1=(a)

# %%
t1
# Out:
# [2, 4, 6, 8, 5, 4, 4]

# %%
t1.count(4)
# Out:
# 3

# %%
t1.index(5)
# Out:
# 4

# %%
set1 = {6 , 6,6,6,6,6,6,7,7,8,54,4,6,7,788,8,9,56,4,68}
set2 = {5,7,9,3,4,7,6,6,6,6,}

# %%
set1 | set2
# Out:
# {3, 4, 5, 6, 7, 8, 9, 54, 56, 68, 788}

# %%
set1 & set2
# Out:
# {4, 6, 7, 9}

# %%
set1 - set2
# Out:
# {8, 54, 56, 68, 788}

# %%
set1 ^ set2
# Out:
# {3, 5, 8, 54, 56, 68, 788}

# %%
set1.add(7)

# %%
set1.remove(7)

# %%
set1
# Out:
# {4, 6, 8, 9, 54, 56, 68, 788}

# %%
4 in set2
# Out:
# True

# %%
set2
# Out:
# {3, 4, 5, 6, 7, 9}

# %%
inter = set1 & set2
set1 = set1 - inter
set2 = set2 - inter
print(set1)
print(set2)
# Out:
# {68, 8, 788, 54, 56}
# {3, 5, 7}

# %%
d = { 'name': 'suhaib' ,
'age':22 ,
'position': 'intern'}

# %%
d
# Out:
# {'name': 'suhaib', 'age': 22, 'position': 'intern'}

# %%
d['name']
# Out:
# 'suhaib'

# %%
d.get('age')
# Out:
# 22

# %%
d['marks']= 99

# %%
d
# Out:
# {'name': 'suhaib', 'age': 22, 'position': 'intern', 'marks': 99}

# %%
d['age']=23

# %%
d
# Out:
# {'name': 'suhaib', 'age': 23, 'position': 'intern', 'marks': 99}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'position', 'marks'])

# %%
d.values()
# Out:
# dict_values(['suhaib', 23, 'intern', 99])

# %%
for key,value in d.items() :
    print(key,' : ',value)
# Out:
# name  :  suhaib
# age  :  23
# position  :  intern
# marks  :  99

# %%
d.items()
# Out:
# dict_items([('name', 'suhaib'), ('age', 23), ('position', 'intern'), ('marks', 99)])

# %%
'name' in d.keys()
# Out:
# True

# %%
for key , value in d.items() :
    if value == 23:
        print(key)
# Out:
# age

# %%
keys1 = ['name1', 'age1','role1']
value1 = ['musi', 4,'intern']

# %%
d1 = {}

# %%
for i in range(len(keys1)) :
    d[keys1[i]] = value1[i]
d
# Out:
# {'name': 'suhaib',
#  'age': 23,
#  'position': 'intern',
#  'marks': 99,
#  'name1': 'musi',
#  'age1': 4,
#  'role1': 'intern'}

# %%
d2 = dict(zip(keys1,value1))

# %%
d2
# Out:
# {'name1': 'musi', 'age1': 4, 'role1': 'intern'}

# %%
Students = { 'suhaib':{'math':30,'cs':10},
             'musaib':{'math':20,'cs':20}
}
Students
# Out:
# {'suhaib': {'math': 30, 'cs': 10}, 'musaib': {'math': 20, 'cs': 20}}

# %%
Students['suhaib']['math']
# Out:
# 30

# %%
Student = { 'suaib':{'math':30,'cs':10},
             'muaib':{'math':20,'cs':20}
}

# %%
def total_marks(Student):
    for i in Student:
        print(sum(Student[i].values()))
total_marks(Student)
# Out:
# 40
# 40

# %%
def total_marks(Student):
    for i in Student:
        print(Student[i].values())
       
total_marks(Student)
# Out:
# dict_values([30, 10])
# dict_values([20, 20])

# %%
def mer(Students,Student):
    Students.update(Student)
    return Students

# %%
mer(Students,Student)
# Out:
# {'suhaib': {'math': 30, 'cs': 10},
#  'musaib': {'math': 20, 'cs': 20},
#  'suaib': {'math': 30, 'cs': 10},
#  'muaib': {'math': 20, 'cs': 20}}

# %%
d11 = {1:  30, 
 5: 20, 
 9: 30, 
4 :  20}

# %%
def srt(d11):
    return dict(zip(sorted(d11.keys()),sorted(d11.values())))

# %%
srt(d11)
# Out:
# {1: 20, 4: 20, 5: 30, 9: 30}
